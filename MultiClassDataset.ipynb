# %%
import pandas as pd
import os
import shutil

# %%
FILE_PATH ='C:\\Users\\harit\\Downloads\\covid-chestxray-dataset-master\\metadata.csv'
IMAGES_PATH ='C:\\Users\\harit\\Downloads\\covid-chestxray-dataset-master\\images'

# %%
df = pd.read_csv(FILE_PATH)
df.head()
# Out:
#   patientid  offset sex   age                   finding RT_PCR_positive  \
# 0         2     0.0   M  65.0  Pneumonia/Viral/COVID-19               Y
# 1         2     3.0   M  65.0  Pneumonia/Viral/COVID-19               Y
# 2         2     5.0   M  65.0  Pneumonia/Viral/COVID-19               Y
# 3         2     6.0   M  65.0  Pneumonia/Viral/COVID-19               Y
# 4         4     0.0   F  52.0  Pneumonia/Viral/COVID-19               Y
#
#   survival intubated intubation_present went_icu  ...              date  \
# 0        Y         N                  N        N  ...  January 22, 2020
# 1        Y         N                  N        N  ...  January 25, 2020
# 2        Y         N                  N        N  ...  January 27, 2020
# 3        Y         N                  N        N  ...  January 28, 2020
# 4      NaN         N                  N        N  ...  January 25, 2020
#
#                                             location  folder  \
# ...

# %%
TARGET_DIR_COVID = "MultiClass\\Covid"
TARGET_DIR_VIRAL = "MultiClass\\Viral"
TARGET_DIR_BACTERIAL = "MultiClass\\Bacterial"
TARGET_DIR_FUNGAL = "MultiClass\\Fungal"
TARGET_DIR_NORMAL = "MultiClass\\Normal"

# %%
TARGET_DIR = "MultiClass"
if not os.path.exists(TARGET_DIR):
    os.makedirs(TARGET_DIR_COVID)
    os.makedirs(TARGET_DIR_VIRAL)
    os.makedirs(TARGET_DIR_BACTERIAL)
    os.makedirs(TARGET_DIR_FUNGAL)
    os.makedirs(TARGET_DIR_NORMAL)
    print("Folder created")

# %%
cnt=1

for (i,row) in df.iterrows():
    if(row["finding"]=="Pneumonia/Viral/COVID-19" and row["folder"]=='images' and(row["view"]=='PA' or row["view"]=='AP' or row["view"]=='AP Erect' or row["view"]=='AP Supine') and row['modality']=='X-ray'):
        filename = row['filename']
        image_path = os.path.join(IMAGES_PATH,(filename))
        image_copy_path = os.path.join(TARGET_DIR_COVID,filename)
        shutil.copy2(image_path,image_copy_path)
        print("moving image ",cnt)
    elif((row["finding"]=='Pneumonia/Viral/SARS' or row["finding"]=='Pneumonia/Viral/MERS-CoV' or row["finding"] =='Pneumonia/Viral/Varicella' or row["finding"]=='Pneumonia/Viral/Influenza' or row["finding"]=='Pneumonia/Viral/Herpes') and row["folder"]=='images' and(row["view"]=='PA' or row["view"]=='AP' or row["view"]=='AP Erect' or row["view"]=='AP Supine') and row['modality']=='X-ray'):
        filename = row['filename']
        image_path = os.path.join(IMAGES_PATH,(filename))
        image_copy_path = os.path.join(TARGET_DIR_VIRAL,filename)
        shutil.copy2(image_path,image_copy_path)
        print("moving image ",cnt)
    elif((row["finding"]=='Pneumonia/Bacterial/Streptococcus' or row["finding"]=='Pneumonia/Bacterial/Klebsiella' or row["finding"]=='Pneumonia/Bacterial/E.Coli' or row["finding"]=='Pneumonia/Bacterial/Nocardia' or row["finding"]=='Pneumonia/Bacterial/Mycoplasma' or row["finding"]=='Pneumonia/Bacterial/Legionella' or row["finding"]=='Pneumonia/Bacterial/Chlamydophila'or row["finding"]=='Pneumonia/Bacterial/Staphylococcus/MRSA') and row["folder"]=='images' and(row["view"]=='PA' or row["view"]=='AP' or row["view"]=='AP Erect' or row["view"]=='AP Supine') and row['modality']=='X-ray'):
        filename = row['filename']
        image_path = os.path.join(IMAGES_PATH,(filename))
        image_copy_path = os.path.join(TARGET_DIR_BACTERIAL,filename)
        shutil.copy2(image_path,image_copy_path)
        print("moving image ",cnt)
    elif((row["finding"] =='Pneumonia/Fungal/Pneumocystis' or row["finding"]=='Pneumonia/Fungal/Aspergillosis') and row["folder"]=='images' and(row["view"]=='PA' or row["view"]=='AP' or row["view"]=='AP Erect' or row["view"]=='AP Supine') and row['modality']=='X-ray'):
        filename = row['filename']
        image_path = os.path.join(IMAGES_PATH,(filename))
        image_copy_path = os.path.join(TARGET_DIR_FUNGAL,filename)
        shutil.copy2(image_path,image_copy_path)
        print("moving image ",cnt)
    cnt+=1
# Out:
# moving image  1
# moving image  2
# moving image  3
# moving image  4
# moving image  5
# moving image  6
# moving image  8
# moving image  9
# moving image  10
# moving image  11
# moving image  12
# moving image  13
# moving image  14
# moving image  15
# moving image  16
# moving image  17
# moving image  18
# moving image  19
# moving image  20
# moving image  21
# moving image  22
# moving image  23
# moving image  25
# moving image  27
# moving image  28
# moving image  30
# moving image  31
# moving image  32
# moving image  33
# moving image  34
# moving image  35
# moving image  36
# moving image  37
# moving image  40
# moving image  41
# moving image  42
# moving image  43
# moving image  44
# moving image  49
# moving image  51
# moving image  52
# moving image  55
# moving image  58
# moving image  62
# moving image  64
# moving image  65
# moving image  66
# moving image  67
# moving image  68
# moving image  69
# moving image  70
# moving image  73
# moving image  76
# ...

# %%
import os
arr = os.listdir('C:\\Users\\harit\\Downloads\\chest_xray\\train\\PNEUMONIA')
print(arr)
len(arr)
# Out:
# ['person1000_bacteria_2931.jpeg', 'person1000_virus_1681.jpeg', 'person1001_bacteria_2932.jpeg', 'person1002_bacteria_2933.jpeg', 'person1003_bacteria_2934.jpeg', 'person1003_virus_1685.jpeg', 'person1004_bacteria_2935.jpeg', 'person1004_virus_1686.jpeg', 'person1005_bacteria_2936.jpeg', 'person1005_virus_1688.jpeg', 'person1006_bacteria_2937.jpeg', 'person1007_bacteria_2938.jpeg', 'person1007_virus_1690.jpeg', 'person1008_bacteria_2939.jpeg', 'person1008_virus_1691.jpeg', 'person1009_virus_1694.jpeg', 'person100_virus_184.jpeg', 'person1010_bacteria_2941.jpeg', 'person1010_virus_1695.jpeg', 'person1011_bacteria_2942.jpeg', 'person1012_bacteria_2943.jpeg', 'person1014_bacteria_2945.jpeg', 'person1015_virus_1701.jpeg', 'person1015_virus_1702.jpeg', 'person1016_bacteria_2947.jpeg', 'person1016_virus_1704.jpeg', 'person1017_bacteria_2948.jpeg', 'person1018_bacteria_2949.jpeg', 'person1018_virus_1706.jpeg', 'person1019_bacteria_2950.jpeg', 'person1019_virus_1707.jpeg', 'person1019_virus_
# ...

# %%
IMAGE_PATH ='C:\\Users\\harit\\Downloads\\chest_xray\\train\\PNEUMONIA'
count =0
for filename in os.listdir(IMAGE_PATH):
    if "bacteria" in filename:
        image_path = os.path.join(IMAGE_PATH,(filename))
        image_copy_path = os.path.join(TARGET_DIR_BACTERIAL,filename)
        shutil.copy2(image_path,image_copy_path)
        print("moving image ",count)
    else:
        image_path = os.path.join(IMAGE_PATH,(filename))
        image_copy_path = os.path.join(TARGET_DIR_VIRAL,filename)
        shutil.copy2(image_path,image_copy_path)
        print("moving image ",count)
count+=1
# Out:
# moving image  0
# moving image  1
# moving image  2
# moving image  3
# moving image  4
# moving image  5
# moving image  6
# moving image  7
# moving image  8
# moving image  9
# moving image  10
# moving image  11
# moving image  12
# moving image  13
# moving image  14
# moving image  15
# moving image  16
# moving image  17
# moving image  18
# moving image  19
# moving image  20
# moving image  21
# moving image  22
# moving image  23
# moving image  24
# moving image  25
# moving image  26
# moving image  27
# moving image  28
# moving image  29
# moving image  30
# moving image  31
# moving image  32
# moving image  33
# moving image  34
# moving image  35
# moving image  36
# moving image  37
# moving image  38
# moving image  39
# moving image  40
# moving image  41
# moving image  42
# moving image  43
# moving image  44
# moving image  45
# moving image  46
# moving image  47
# moving image  48
# moving image  49
# moving image  50
# moving image  51
# moving image  52
# ...

# %%
IMAGE_PATH1 ='C:\\Users\\harit\\Downloads\\chest_xray\\test\\PNEUMONIA'
count =0
for filename in os.listdir(IMAGE_PATH1):
    if "bacteria" in filename:
        image_path = os.path.join(IMAGE_PATH1,(filename))
        image_copy_path = os.path.join(TARGET_DIR_BACTERIAL,filename)
        shutil.copy2(image_path,image_copy_path)
        print("moving image ",count)
    else:
        image_path = os.path.join(IMAGE_PATH1,(filename))
        image_copy_path = os.path.join(TARGET_DIR_VIRAL,filename)
        shutil.copy2(image_path,image_copy_path)
        print("moving image ",count)
    count+=1
# Out:
# moving image  0
# moving image  1
# moving image  2
# moving image  3
# moving image  4
# moving image  5
# moving image  6
# moving image  7
# moving image  8
# moving image  9
# moving image  10
# moving image  11
# moving image  12
# moving image  13
# moving image  14
# moving image  15
# moving image  16
# moving image  17
# moving image  18
# moving image  19
# moving image  20
# moving image  21
# moving image  22
# moving image  23
# moving image  24
# moving image  25
# moving image  26
# moving image  27
# moving image  28
# moving image  29
# moving image  30
# moving image  31
# moving image  32
# moving image  33
# moving image  34
# moving image  35
# moving image  36
# moving image  37
# moving image  38
# moving image  39
# moving image  40
# moving image  41
# moving image  42
# moving image  43
# moving image  44
# moving image  45
# moving image  46
# moving image  47
# moving image  48
# moving image  49
# moving image  50
# moving image  51
# moving image  52
# ...

# %%
COVIDTR_PATH ='C:\\Users\\harit\\Downloads\\Data\\train\\COVID19'
count =0
for filename in os.listdir(COVIDTR_PATH):
    if "COVID19" in filename:
        image_path = os.path.join(COVIDTR_PATH,(filename))
        image_copy_path = os.path.join(TARGET_DIR_COVID,filename)
        shutil.copy2(image_path,image_copy_path)
    count+=1

# %%
COVIDTR_PATH1 ='C:\\Users\\harit\\Downloads\\Data\\test\\COVID19'
count =0
for filename in os.listdir(COVIDTR_PATH1):
    if "COVID19" in filename:
        image_path = os.path.join(COVIDTR_PATH1,(filename))
        image_copy_path = os.path.join(TARGET_DIR_COVID,filename)
        shutil.copy2(image_path,image_copy_path)
        print("moving image ",count)
    count+=1
# Out:
# moving image  0
# moving image  1
# moving image  2
# moving image  3
# moving image  4
# moving image  5
# moving image  6
# moving image  7
# moving image  8
# moving image  9
# moving image  10
# moving image  11
# moving image  12
# moving image  13
# moving image  14
# moving image  15
# moving image  16
# moving image  17
# moving image  18
# moving image  19
# moving image  20
# moving image  21
# moving image  22
# moving image  23
# moving image  24
# moving image  25
# moving image  26
# moving image  27
# moving image  28
# moving image  29
# moving image  30
# moving image  31
# moving image  32
# moving image  33
# moving image  34
# moving image  35
# moving image  36
# moving image  37
# moving image  38
# moving image  39
# moving image  40
# moving image  41
# moving image  42
# moving image  43
# moving image  44
# moving image  45
# moving image  46
# moving image  47
# moving image  48
# moving image  49
# moving image  50
# moving image  51
# moving image  52
# ...
